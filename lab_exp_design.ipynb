# %% [markdown]
# <a href="https://colab.research.google.com/github/pdesire-20/Lab6/blob/main/lab_exp_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions. For this lab, we will be using a dataset of questions and answers from the STAT 107 class in Spring 2024.

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-sp24.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df` -- and **don't forget to import pandas**! :)

# %%
import pandas as pd

df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-sp24.csv")

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Do you like sweet or savory food?',
#  'Do you use Windows or Mac?',
#  "Do you like doing your homework when it's released or in the end?",
#  'Are you a morning person?',
#  'Are you following the data science duo on Instagram? @datascienceduo',
#  'Dairy or non-dairy?',
#  'Are you an In-State or Out-of-State student?',
#  'Have you watched Saltburn?',
#  "In the last lecture, did you sit on the left side or the right of the lecture room (if you're facing Karle and Wade)?",
#  'KAMS (Key Axioms in Mathematical Statistics) or LION (Linearly Independent Orthogonal Nullspaces)',
#  'Cool Ranch Doritos or Nacho Cheese Doritos? ',
#  'Do you like math or not?',
#  'Chocolate or Vanilla Ice Cream?',
#  'Flip a coin, is it heads or tails?',
#  'Did you live in the six-pack/IKE your freshman year?',
#  'Do you prefer pizza or burgers?',
#  'Are you an introvert or extrovert?',
#  'Do you prefer coffee or tea?',
#  'Check the time -- is it even or odd?',
#  'Do you prefer waffles or pancakes?',
#  'Do you prefer to wear dark colors or light colors?',
#  'What came first, the chicken or the egg?',
#  'Do you prefer Taylor Swift or Beyoncé?',
#  'Do you prefer shows or movies?',
#  'Are you a Swiftie?',
#  'Is water wet?',
#  'Do you like pineapple on pizza?',
#  'Do you prefer Home Alone 1 or Home Alone 2?',
#  'Do you prefer salty or sweet snacks?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you prefer summer or winter?',
#  'Would you rather the super power of invisibility or of reading minds?',
#  'Did you go to DISCOVERY on Friday?',
#  'Out of these 2 numbers which one do you like more? 239,238,134,821 or 239,238,124,821?',
#  'Is your major in the college of LAS?',
#  'Are you from the greater Chicagoland area?',
#  'Do you have a pet?',
#  'Did you watch SpongeBob growing up?',
#  'Is this your first year in college?',
#  'What is scarier: Snakes or Spiders?',
#  'Pick one A or B?',
#  'American Football or Basketball?',
#  'Are you male?',
#  'Do you like Barbie or Oppenheimer more?',
#  'Do you prefer Spring or Fall?',
#  'McDonalds or Burger King?',
#  'What type of weather do you prefer, hot or cold?',
#  'Do you prefer Pop or Hip-Hop music?',
#  'Is DISCOVERY hard?',
#  'What is your favorite baseball team?',
#  'Are all of your class buildings on the main quad?',
#  'Do you prefer red or blue?',
#  'Do you prefer Dr. Pepper or Pepsi?',
#  'Coke or Pepsi? ',
#  'Does your UIN end in an even or odd number?',
#  'Do you prefer eating chicken or beef?',
#  'Have you attend a football game in UIUC?',
#  'Do you like breakfast or lunch better?',
#  'Which number do you like more, 3 or 5?',
#  'Is DISCOVERY required for you?',
#  'Do you prefer Ketchup or Mustard?',
#  'Statistics or Computer Science',
#  'Is the dress debate from 2015 blue/black or white/gold?  (Search "the dress" to find the picture if you don\'t remember it!)',
#  'Do you prefer the color black or white?',
#  'Do you have a birthday in the first 6 month or the last 6 months?',
#  'Do you prefer spicy or sweet food?',
#  'Do you prefer tacos or burgers?',
#  'Would you rather drink coke or sprite for the rest of your life?',
#  'Do you prefer Christmas or Halloween?',
#  'Would you rather be able to forget your worst memory or be able to remember your best memory better?',
#  'Would you rather attend classes in the morning or in the afternoon?',
#  'Would you rather drive or be the passenger?',
#  'Are you a morning or night person?',
#  'Do you like iced or hot coffee?',
#  'Do you like your dad more or your mom more?',
#  'Do you prefer Italian food or Mexican food?',
#  'Do you have hair long hair?',
#  'Light mode or dark mode?',
#  'Do you prefer cool colors or warm colors?',
#  'Do you listen to music on your way to classes?',
#  'Do you have a job?',
#  'Is math red or blue?',
#  'Would you prefer group work or solo work?',
#  'Do you prefer pop or rap music?',
#  'Do you prefer math or english more?',
#  'Do you prefer coffee or milk? ',
#  'Do you like dogs?',
#  'Were you born in China?',
#  'Do you like exercising?',
#  'Are you a statistics major?',
#  'Where you born in 2004? ',
#  'Do you prefer books or movies?',
#  'Do you prefer pasta or pizza?',
#  'Is your weekly STAT107 lab session before or after 10:55 am on Thursday?',
#  'Are you in Gies or trying to get into Gies?',
#  'Dark Chocolate or Milk Chocolate?',
#  'Starbucks or Dunkin?',
#  'Do you live a dorm?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you like ice cream in winter?',
#  'Do you sleep more than 7 hours a night?',
#  'Do you need a prescription to see?',
#  'Do you play games?',
#  'Apples or pears?',
#  'Do you plan to double major?',
#  'Are you an international student or a domestic student?',
#  'Do you prefer to sit in the front or the back of a class?',
#  'Do you prefer Nike or Adidas?',
#  'Do you take the bus to class?',
#  'Do you prefer in-person or online classes? ',
#  'Do you prefer the zoo or the aquarium?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'From 1 to 10, how happy are you right now?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'Favorite on campus restaurant? ',
#  'Favorite place to study on campus?',
#  'What genre of music do you like the most?',
#  'What is your favorite school subject?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# Select a question from this list to explore for this lab.
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column =  'Do you live a dorm?'
analysis_column
# Out:
# 'Do you live a dorm?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 576 and len(df) < 700), "You have not loaded the correct Hello Dataset."
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time.
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df [[analysis_column] ]
# Out:
#     Do you live a dorm?
# 0                    No
# 1                    No
# 2                    No
# 3                   Yes
# 4                    No
# ..                  ...
# 606                 Yes
# 607                 Yes
# 608                  No
# 609                 Yes
# 610                 Yes
#
# [611 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == "No"]
df1
# Out:
#             Name Section Do you like sweet or savory food?  \
# 0    Prof. Karle     AL1                            Savory
# 1     Prof. Wade     AL1                            Savory
# 2        Raymond     Y17                            Savory
# 4            Ash     Y17                             Sweet
# 5      CA Sophia     Y02                            Savory
# ..           ...     ...                               ...
# 595       Farwah     Y16                            Savory
# 596      Abhinav     Y13                            Savory
# 599         ecat     Y20                            Savory
# 602        Tasso     Y12                            Savory
# 608       Afnaan     Y01                            Savory
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 1                      Windows
# 2                      Windows
# 4                      Windows
# 5                          Mac
# ..                         ...
# 595                        Mac
# 596                        Mac
# 599                        Mac
# 602                    Windows
# 608                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 1                                   When it's released
# 2                                   When it's released
# 4                                   When it's released
# 5                                   When it's released
# ..                                                 ...
# 595                                       Near the end
# 596                                       Near the end
# 599                                       Near the end
# 602                                       Near the end
# 608                                       Near the end
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 1        NOT a Morning Person
# 2              Morning Person
# 4        NOT a Morning Person
# 5              Morning Person
# ..                        ...
# 595            Morning Person
# 596      NOT a Morning Person
# 599            Morning Person
# 602      NOT a Morning Person
# 608      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 4                                                   No
# 5                                                  Yes
# ..                                                 ...
# 595                                                Yes
# 596                                                 No
# 599                                                Yes
# 602                                                 No
# 608                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 1                 Dairy                                     In-State
# 2                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# 5             Non-dairy                                     In-State
# ..                  ...                                          ...
# 595               Dairy                                     In-State
# 596               Dairy                                 Out-of-State
# 599               Dairy                                     In-State
# 602               Dairy                                     In-State
# 608               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 0                          Yes  ...
# 1                           No  ...
# 2                           No  ...
# 4                           No  ...
# 5                          Yes  ...
# ..                         ...  ...
# 595                         No  ...
# 596                         No  ...
# 599                        Yes  ...
# 602                        Yes  ...
# 608                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 0                                             Maldives
# 1                                              Sweeden
# 2                                                China
# 4                                                Italy
# 5                                               Greece
# ..                                                 ...
# 595                                                 uk
# 596                                             France
# 599                                              italy
# 602                                        switzerland
# 608                                              India
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 0                              Za's                      Cafe Paradiso
# 1                    Shawarma Joint                      Siebel Center
# 2                       Kung Fu BBQ                               Home
# 4                      Burrito King                      Cafe Paradiso
# 5                       thai fusion                                CIF
# ..                              ...                                ...
# 595                   bangkok thai      grainger second floor with sun
# 596                        Chipotle                          Siebel CS
# 599                     kung fu tea                       main library
# 602                         mia zas                           room 102
# 608                    Bangkok Thai                                CIF
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 1                                         Pop
# 2                                         RnB
# 4                                         Pop
# 5                                   pop/indie
# ..                                        ...
# 595                                       pop
# 596                                   Hip Hop
# 599                                     indie
# 602                                       rap
# 608                                       pop
#
#     What is your favorite school subject?  \
# 0                                    math
# 1                                      CS
# 2                                 History
# 4                                   Stats
# 5                                    Math
# ..                                    ...
# 595                                  math
# 596                               Finance
# 599                                  math
# 602                               History
# 608                               Science
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 1                                  Computer Science
# 2                                               ECE
# 4                                       Engineering
# 5                                              ECE
# ..                                              ...
# 595                               comp engineering
# 596                            Chemical Engineering
# 599                                              cs
# 602                                              CS
# 608                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 1                         Taylor Swift                                YouTube
# 2                          Alan Walker                              Instagram
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# 5                      Phoebe Bridgers                              Instagram
# ..                                 ...                                    ...
# 595                        tate mcrae                                  tiktok
# 596                          Anuv Jain                               LinkedIn
# 599                       Taylor swift                              pinterest
# 602                              drake                                  insta
# 608                              Drake                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 1                                             Factorio
# 2                                            Minecraft
# 4                                              Pokemon
# 5                                             Fortnite
# ..                                                 ...
# 595                                              mafia
# 596                                          Beer Pong
# 599                              card against humanity
# 602                                           baseball
# 608                                         Mario Kart
#
#     Where is your dream vacation spot?
# 0                             Maldives
# 1                            Mountains
# 2                                China
# 4                              Itality
# 5                               Greece
# ..                                 ...
# 595                             london
# 596                             Norway
# 599                              italy
# 602                            iceland
# 608                               Bali
#
# [295 rows x 133 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == "Yes"]
df2
# Out:
#           Name Section Do you like sweet or savory food?  \
# 3        Keiji     Y13                             Sweet
# 6          Max     Y02                            Savory
# 8       Prisha     Y10                            Savory
# 9        Elise     Y03                             Sweet
# 11   Christian     Y13                             Sweet
# ..         ...     ...                               ...
# 605   LaKeisha     Y15                            Savory
# 606   Jonathan     Y20                             Sweet
# 607        Leo     Y19                             Sweet
# 609     Nathan     Y17                             Sweet
# 610      Ellyn     Y2-                            Savory
#
#     Do you use Windows or Mac?  \
# 3                      Windows
# 6                      Windows
# 8                          Mac
# 9                          Mac
# 11                         Mac
# ..                         ...
# 605                        Mac
# 606                        Mac
# 607                        Mac
# 609                    Windows
# 610                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 3                                   When it's released
# 6                                         Near the end
# 8                                         Near the end
# 9                                         Near the end
# 11                                        Near the end
# ..                                                 ...
# 605                                 When it's released
# 606                                 When it's released
# 607                                       Near the end
# 609                                 When it's released
# 610                                       Near the end
#
#     Are you a morning person?  \
# 3              Morning Person
# 6        NOT a Morning Person
# 8        NOT a Morning Person
# 9        NOT a Morning Person
# 11       NOT a Morning Person
# ..                        ...
# 605      NOT a Morning Person
# 606            Morning Person
# 607      NOT a Morning Person
# 609            Morning Person
# 610      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 3                                                  Yes
# 6                                                  Yes
# 8                                                  Yes
# 9                                                  Yes
# 11                                                  No
# ..                                                 ...
# 605                                                Yes
# 606                                                 No
# 607                                                 No
# 609                                                 No
# 610                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 3                 Dairy                                     In-State
# 6                 Dairy                                 Out-of-State
# 8                 Dairy                                     In-State
# 9             Non-dairy                                          NaN
# 11                Dairy                                     In-State
# ..                  ...                                          ...
# 605           Non-dairy                                     In-State
# 606           Non-dairy                                 Out-of-State
# 607               Dairy                                 Out-of-State
# 609               Dairy                                     In-State
# 610               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 3                           No  ...
# 6                           No  ...
# 8                           No  ...
# 9                          Yes  ...
# 11                          No  ...
# ..                         ...  ...
# 605                         No  ...
# 606                         No  ...
# 607                         No  ...
# 609                         No  ...
# 610                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 3                                                japan
# 6                                                China
# 8                                                Italy
# 9                                                  NaN
# 11                                             England
# ..                                                 ...
# 605                                            Greece
# 606                                              Japan
# 607                                             Taiwan
# 609                                             Norway
# 610                                              Korea
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 3                              yogi                               main
# 6                          Chipotle                               Home
# 8                   Signature Grill                   Grainger Library
# 9                               NaN                                NaN
# 11                         Chipotle                            My dorm
# ..                              ...                                ...
# 605                        Juanitos                                CIF
# 606                             Evo                               Dorm
# 607                Northern Cuisine                            My dorm
# 609                       McDonalds                            Library
# 610                 Northern Cusine                                CIF
#
#     What genre of music do you like the most?  \
# 3                                         rap
# 6                                         Pop
# 8                                         Rap
# 9                                         NaN
# 11                                        Rap
# ..                                        ...
# 605                                   Hip hop
# 606                                       Pop
# 607                                     J-pop
# 609                                     R & B
# 610                                       Rap
#
#     What is your favorite school subject?  \
# 3                                    math
# 6                                   Stats
# 8                                    Math
# 9                                     NaN
# 11                                History
# ..                                    ...
# 605                                   Idk
# 606                               Finance
# 607                                  Math
# 609                        Social Studies
# 610                               English
#
#     What do you think is the hardest major at UIUC?  \
# 3                                          pre med
# 6                                           Physics
# 8                            Electrical Engineering
# 9                                               NaN
# 11                                      Engineering
# ..                                              ...
# 605                                         Physics
# 606                                              EE
# 607                          Electrical Engineering
# 609                            Computer Engineering
# 610                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 3                          post malone                                  insta
# 6                             Coldplay                                WeChat
# 8                                Drake                              Instagram
# 9                         taylor swift                              pinterest
# 11                              Polo G                                Tik Tok
# ..                                 ...                                    ...
# 605                                Idk                                TikTok
# 606                            Yoasobi                                   Line
# 607                Lilas Ikuta (Ikura)                               Facebook
# 609                      Daniel Ceaser                              Instagram
# 610                        Don Toliver                                 Tiktok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                                      clash of clans
# 6                                          Hearthstone
# 8                                                World
# 9                                                  NaN
# 11                                                FIFA
# ..                                                 ...
# 605                                              WiiU
# 606                                            Genshin
# 607                                     Genshin Impact
# 609                                           Fortnite
# 610                                      Hide and Seek
#
#     Where is your dream vacation spot?
# 3                               greece
# 6                             Maldives
# 8                                Italy
# 9                                  NaN
# 11                              Taiwan
# ..                                 ...
# 605                          Bora Bora
# 606                             Europe
# 607                             Hawaii
# 609                      Venice, Italy
# 610                        Switzerland
#
# [313 rows x 133 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %%
len(df1), len(df2),
# Out:
# (295, 313)

# %%
len(df1)/len(df)
# Out:
# 0.4828150572831424

# %%
len(df2)/len(df)
# Out:
# 0.5122749590834698

# %% [markdown]
# Yes: 48%
#
# No: 51%

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# Because studen't don't like living in Dorms.

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# Yes, I would say so: 48% & 51%.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# **Randomly** select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#                 Name   Section Do you like sweet or savory food?  \
# 184          William       Y10                             Sweet
# 193            Suvid       Y02                            Savory
# 175        CA Eliana       Y20                            Savory
# 334          Matilda       Y01                            Savory
# 105          Richard       Y06                            Savory
# ..               ...       ...                               ...
# 349             Matt       Y13                             Sweet
# 15           Brendan       Y18                            Savory
# 46   Oluwafayosikemi       Y18                            Savory
# 431             Garv       Y14                            Savory
# 559           CA Jai  Y01, Y16                             Sweet
#
#     Do you use Windows or Mac?  \
# 184                        Mac
# 193                    Windows
# 175                    Windows
# 334                        Mac
# 105                        Mac
# ..                         ...
# 349                    Windows
# 15                     Windows
# 46                         Mac
# 431                        Mac
# 559                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 184                                 When it's released
# 193                                 When it's released
# 175                                       Near the end
# 334                                       Near the end
# 105                                 When it's released
# ..                                                 ...
# 349                                       Near the end
# 15                                  When it's released
# 46                                  When it's released
# 431                                       Near the end
# 559                                       Near the end
#
#     Are you a morning person?  \
# 184            Morning Person
# 193      NOT a Morning Person
# 175      NOT a Morning Person
# 334      NOT a Morning Person
# 105      NOT a Morning Person
# ..                        ...
# 349      NOT a Morning Person
# 15             Morning Person
# 46       NOT a Morning Person
# 431      NOT a Morning Person
# 559      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 184                                                 No
# 193                                                 No
# 175                                                Yes
# 334                                                NaN
# 105                                                 No
# ..                                                 ...
# 349                                                 No
# 15                                                  No
# 46                                                  No
# 431                                                 No
# 559                                                Yes
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 184               Dairy                                     In-State
# 193               Dairy                                 Out-of-State
# 175           Non-dairy                                     In-State
# 334           Non-dairy                                     In-State
# 105               Dairy                                     In-State
# ..                  ...                                          ...
# 349               Dairy                                     In-State
# 15                Dairy                                     In-State
# 46                Dairy                                     In-State
# 431           Non-dairy                                 Out-of-State
# 559           Non-dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 184                         No  ...
# 193                        Yes  ...
# 175                        Yes  ...
# 334                        Yes  ...
# 105                         No  ...
# ..                         ...  ...
# 349                        Yes  ...
# 15                          No  ...
# 46                          No  ...
# 431                         No  ...
# 559                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 184                                             Mexico
# 193                                              India
# 175                                              Japan
# 334                                             Norway
# 105                                              Korea
# ..                                                 ...
# 349                                        Netherlands
# 15                                               Japan
# 46                                             Nigeria
# 431                                              italy
# 559                                         Costa Rica
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 184                           Canes                               Dorm
# 193                     Ambar India                           Grainger
# 175                  Shawarma Joint                       Main Library
# 334                        Chopstix                Sidney Lu Starbucks
# 105                        Evo Cafe                      Saunders Hall
# ..                              ...                                ...
# 349                    Bangkok Thai                   Grainger Library
# 15                     Fat Sandwich                                BIF
# 46                Noodles & Company                       Main Library
# 431                    Burrito king                       lincoln hall
# 559                        Watson's                          Cafe Bene
#
#     What genre of music do you like the most?  \
# 184                                   Mexican
# 193                                       Pop
# 175                                       Pop
# 334                                 surf rock
# 105                                      CPOP
# ..                                        ...
# 349                                      Rock
# 15                                        Rap
# 46                                Afro beats
# 431                                       pop
# 559                                       EDM
#
#     What is your favorite school subject?  \
# 184                                  Math
# 193                                    CS
# 175                               Science
# 334                  anything about data!
# 105                                  Math
# ..                                    ...
# 349                                  Math
# 15                           Data Science
# 46                               English
# 431                                  Math
# 559                                  Math
#
#     What do you think is the hardest major at UIUC?  \
# 184                                     Engineering
# 193                            Computer Engineering
# 175                            Computer Engineering
# 334                                          Comp E
# 105                             Electrical Engineer
# ..                                              ...
# 349                                Computer Science
# 15                                               CS
# 46                                       Statistics
# 431                                              CS
# 559                                             ECE
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 184                           Junior H                                 Tiktok
# 193                         Juice WRLD                              Instagram
# 175                       Taylor Swift                              Goodreads
# 334                       taylor swift                                 tiktok
# 105                                NaN                                 TikTok
# ..                                 ...                                    ...
# 349                       Foo Fighters                                 Tiktok
# 15                           21 Savage                              Instagram
# 46                              Davido                              Instagram
# 431                               russ                             instagram
# 559                           Coldplay                                 Reddit
#
#     What is your favorite game to play (either video game or IRL)?  \
# 184                                               Fifa
# 193                                           Valorant
# 175                                            Pokemon
# 334                                                 BS
# 105                                  League of Legends
# ..                                                 ...
# 349                                           Fortnite
# 15                                          Basketball
# 46                                                PUBG
# 431                                          Baskeball
# 559                                               FIFA
#
#     Where is your dream vacation spot?
# 184                             Mexico
# 193                             Norway
# 175                              Japan
# 334                              italy
# 105                              China
# ..                                 ...
# 349                          Singapore
# 15                               Japan
# 46                         Switzerland
# 431                            bahamas
# 559                               Bali
#
# [306 rows x 133 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also randomly select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#         Name   Section Do you like sweet or savory food?  \
# 146  TA Alex  Y03, Y20                             Sweet
# 147   Akshaj       Y04                             Sweet
# 408      Liz       Y17                            Savory
# 47       wen       Y18                            Savory
# 572   Sayuj        Y08                             Sweet
# ..       ...       ...                               ...
# 469   Parker       Y01                            Savory
# 423    Tanav       Y20                            Savory
# 348     Tori       Y11                            Savory
# 108   Andrei       Y20                            Savory
# 121   Amelie       Y13                             Sweet
#
#     Do you use Windows or Mac?  \
# 146                        Mac
# 147                        Mac
# 408                        Mac
# 47                         Mac
# 572                    Windows
# ..                         ...
# 469                        Mac
# 423                    Windows
# 348                        Mac
# 108                    Windows
# 121                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 146                                 When it's released
# 147                                 When it's released
# 408                                       Near the end
# 47                                        Near the end
# 572                                 When it's released
# ..                                                 ...
# 469                                       Near the end
# 423                                 When it's released
# 348                                       Near the end
# 108                                 When it's released
# 121                                 When it's released
#
#     Are you a morning person?  \
# 146            Morning Person
# 147            Morning Person
# 408      NOT a Morning Person
# 47       NOT a Morning Person
# 572            Morning Person
# ..                        ...
# 469            Morning Person
# 423      NOT a Morning Person
# 348      NOT a Morning Person
# 108      NOT a Morning Person
# 121      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 146                                                 No
# 147                                                 No
# 408                                                 No
# 47                                                  No
# 572                                                Yes
# ..                                                 ...
# 469                                                 No
# 423                                                 No
# 348                                                 No
# 108                                                 No
# 121                                                Yes
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 146               Dairy                                 Out-of-State
# 147               Dairy                                     In-State
# 408           Non-dairy                                     In-State
# 47            Non-dairy                                 Out-of-State
# 572               Dairy                                 Out-of-State
# ..                  ...                                          ...
# 469               Dairy                                     In-State
# 423               Dairy                                 Out-of-State
# 348           Non-dairy                                     In-State
# 108               Dairy                                     In-State
# 121               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 146                         No  ...
# 147                         No  ...
# 408                        Yes  ...
# 47                          No  ...
# 572                        Yes  ...
# ..                         ...  ...
# 469                        Yes  ...
# 423                        Yes  ...
# 348                        Yes  ...
# 108                         No  ...
# 121                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 146                                             Canada
# 147                                              spain
# 408                                           Bulgaria
# 47                                              China
# 572                                             India
# ..                                                 ...
# 469                                                Rio
# 423                                     United Kingdom
# 348                                              Spain
# 108                                            Denmark
# 121                                              Italy
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 146                     Kung Fu BBQ                         Tech Plaza
# 147                      Oozu Ramen                         Union Cafe
# 408               Strawberry Fields                   Grainger Library
# 47                      sticky rice                               home
# 572                       Taco bell                               Cif
# ..                              ...                                ...
# 469                        Sakanaya    IS building on sixth and daniel
# 423                    Bangkok Thai                                BIF
# 348                         Bangkok                       Main Library
# 108                        Mia Za's                               Dorm
# 121                          Cane's                            Library
#
#     What genre of music do you like the most?  \
# 146                                  Brit-pop
# 147                                      Rock
# 408                                    techno
# 47                                  blue jazz
# 572                                       Rap
# ..                                        ...
# 469                   Old classics or country
# 423                                   Hip-Hop
# 348                                     Indie
# 108                                 Weirdcore
# 121                                       R&B
#
#     What is your favorite school subject?  \
# 146                           Mathematics
# 147                                  Math
# 408                            Statistics
# 47                                   econ
# 572                                  Math
# ..                                    ...
# 469                    Physics/ Mechanics
# 423                                  Math
# 348                                  Math
# 108                                  Math
# 121                                  Math
#
#     What do you think is the hardest major at UIUC?  \
# 146                                     Mathematics
# 147                           Physical + Math minor
# 408                             Nuclear Engineering
# 47                                              cs
# 572                               Computer science
# ..                                              ...
# 469                                             ECE
# 423                                Computer Science
# 348                                         Physics
# 108                            Computer Engineering
# 121                                Computer Science
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 146                       Scott Joplin                              Instagram
# 147                            Rihanna                                Youtube
# 408                    Pierce the Veil                                Twitter
# 47                         Fang datong                                 wechat
# 572                           Coldplay                                  Insta
# ..                                 ...                                    ...
# 469                            J. Cole                              Instagram
# 423                       Travis Scott                              Instagram
# 348                       Taylor Swift                                   VSCO
# 108                Panic at the Disco!                                 Reddit
# 121                         Kanye West                                 TikTok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 146                                          Minecraft
# 147                             Cards against Humanity
# 408                                  World of Warcraft
# 47                                                 NaN
# 572                                          Fortnite
# ..                                                 ...
# 469                                           Fortnite
# 423                                         Basketball
# 348                                     Subway Surfers
# 108                                    Baulders Gate 3
# 121                                          Minecraft
#
#     Where is your dream vacation spot?
# 146                               Moon
# 147                        New Zealand
# 408                            Morroco
# 47                                home
# 572                          Maldives
# ..                                 ...
# 469                        Europe trip
# 423                            Bahamas
# 348                          Bora Bora
# 108                              Japan
# 121                              Italy
#
# [306 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#            Name   Section Do you like sweet or savory food?  \
# 4           Ash       Y17                             Sweet
# 7     CA Alyssa       Y07                             Sweet
# 15      Brendan       Y18                            Savory
# 18          Max       Y10                            Savory
# 26         Mary       Y09                            Savory
# ..          ...       ...                               ...
# 569  TA Shuning  Y06, Y12                            Savory
# 581    TA Ridha  Y09, Y16                            Savory
# 583   CA Anchal       Y04                            Savory
# 595      Farwah       Y16                            Savory
# 602       Tasso       Y12                            Savory
#
#     Do you use Windows or Mac?  \
# 4                      Windows
# 7                          Mac
# 15                     Windows
# 18                         Mac
# 26                     Windows
# ..                         ...
# 569                        Mac
# 581                        Mac
# 583                        Mac
# 595                        Mac
# 602                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 4                                   When it's released
# 7                                         Near the end
# 15                                  When it's released
# 18                                        Near the end
# 26                                        Near the end
# ..                                                 ...
# 569                                       Near the end
# 581                                 When it's released
# 583                                       Near the end
# 595                                       Near the end
# 602                                       Near the end
#
#     Are you a morning person?  \
# 4        NOT a Morning Person
# 7              Morning Person
# 15             Morning Person
# 18       NOT a Morning Person
# 26       NOT a Morning Person
# ..                        ...
# 569      NOT a Morning Person
# 581            Morning Person
# 583      NOT a Morning Person
# 595            Morning Person
# 602      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 4                                                   No
# 7                                                  Yes
# 15                                                  No
# 18                                                  No
# 26                                                 Yes
# ..                                                 ...
# 569                                                 No
# 581                                                 No
# 583                                                 No
# 595                                                Yes
# 602                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 4                 Dairy                                     In-State
# 7             Non-dairy                                     In-State
# 15                Dairy                                     In-State
# 18                Dairy                                 Out-of-State
# 26                Dairy                                     In-State
# ..                  ...                                          ...
# 569               Dairy                                 Out-of-State
# 581               Dairy                                 Out-of-State
# 583               Dairy                                     In-State
# 595               Dairy                                     In-State
# 602               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 4                           No  ...
# 7                          Yes  ...
# 15                          No  ...
# 18                          No  ...
# 26                         Yes  ...
# ..                         ...  ...
# 569                         No  ...
# 581                         No  ...
# 583                         No  ...
# 595                         No  ...
# 602                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 4                                                Italy
# 7                                              england
# 15                                               Japan
# 18                                               Japan
# 26                                               Spain
# ..                                                 ...
# 569                                       Switzerland
# 581                                             Norway
# 583                                         Australia
# 595                                                 uk
# 602                                        switzerland
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 4                      Burrito King                      Cafe Paradiso
# 7                      bangkok thai                       main library
# 15                     Fat Sandwich                                BIF
# 18                         Chipotle                                Hub
# 26                       Ozuu Ramen                      Cafe Paradiso
# ..                              ...                                ...
# 569                            yogi                  Graniger Library
# 581                      Signature                            Grainger
# 583                     Thai Fusion                            My room
# 595                   bangkok thai      grainger second floor with sun
# 602                         mia zas                           room 102
#
#     What genre of music do you like the most?  \
# 4                                         Pop
# 7                                         pop
# 15                                        Rap
# 18                                       JPop
# 26                                      Indie
# ..                                        ...
# 569                                     k-pop
# 581                                Classical
# 583                                       Pop
# 595                                       pop
# 602                                       rap
#
#     What is your favorite school subject?  \
# 4                                   Stats
# 7                              statistics
# 15                           Data Science
# 18                              badminton
# 26                                Science
# ..                                    ...
# 569                               history
# 581                          Mathematics
# 583                               Science
# 595                                  math
# 602                               History
#
#     What do you think is the hardest major at UIUC?  \
# 4                                       Engineering
# 7                                               ece
# 15                                               CS
# 18                                             mine
# 26                                          Biology
# ..                                              ...
# 569                                              CS
# 581                                             ECE
# 583                                              CS
# 595                               comp engineering
# 602                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# 7                        one direction                                twitter
# 15                           21 Savage                              Instagram
# 18                           Yorushika                              Instagram
# 26                 My Bloody Valentine                                 TikTok
# ..                                 ...                                    ...
# 569                          blackpink                                 WeChat
# 581                            Mozart                                 WhatApp
# 583                              Drake                                 Tiktok
# 595                        tate mcrae                                  tiktok
# 602                              drake                                  insta
#
#     What is your favorite game to play (either video game or IRL)?  \
# 4                                              Pokemon
# 7                                       stardew valley
# 15                                          Basketball
# 18                                      Lethal Company
# 26                                          Mario Kart
# ..                                                 ...
# 569                                   Goose Goose Duck
# 581                                          Overwatch
# 583                                 I don’t play games
# 595                                              mafia
# 602                                           baseball
#
#     Where is your dream vacation spot?
# 4                              Itality
# 7                                japan
# 15                               Japan
# 18                           Singapore
# 26                               Spain
# ..                                 ...
# 569                               Fuji
# 581                           Istanbul
# 583                           Iceland
# 595                             london
# 602                            iceland
#
# [146 rows x 133 columns]

# %% [markdown]
# **Q4: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# *It's selecting the people from the entire list.

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[~df.index.isin(treatment.index)]
control
# Out:
#            Name Section Do you like sweet or savory food?  \
# 1    Prof. Wade     AL1                            Savory
# 5     CA Sophia     Y02                            Savory
# 6           Max     Y02                            Savory
# 9         Elise     Y03                             Sweet
# 13       Isaiah     Y02                             Sweet
# ..          ...     ...                               ...
# 606    Jonathan     Y20                             Sweet
# 607         Leo     Y19                             Sweet
# 608      Afnaan     Y01                            Savory
# 609      Nathan     Y17                             Sweet
# 610       Ellyn     Y2-                            Savory
#
#     Do you use Windows or Mac?  \
# 1                      Windows
# 5                          Mac
# 6                      Windows
# 9                          Mac
# 13                         Mac
# ..                         ...
# 606                        Mac
# 607                        Mac
# 608                        Mac
# 609                    Windows
# 610                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 1                                   When it's released
# 5                                   When it's released
# 6                                         Near the end
# 9                                         Near the end
# 13                                  When it's released
# ..                                                 ...
# 606                                 When it's released
# 607                                       Near the end
# 608                                       Near the end
# 609                                 When it's released
# 610                                       Near the end
#
#     Are you a morning person?  \
# 1        NOT a Morning Person
# 5              Morning Person
# 6        NOT a Morning Person
# 9        NOT a Morning Person
# 13       NOT a Morning Person
# ..                        ...
# 606            Morning Person
# 607      NOT a Morning Person
# 608      NOT a Morning Person
# 609            Morning Person
# 610      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 1                                                  Yes
# 5                                                  Yes
# 6                                                  Yes
# 9                                                  Yes
# 13                                                  No
# ..                                                 ...
# 606                                                 No
# 607                                                 No
# 608                                                 No
# 609                                                 No
# 610                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 1                 Dairy                                     In-State
# 5             Non-dairy                                     In-State
# 6                 Dairy                                 Out-of-State
# 9             Non-dairy                                          NaN
# 13                Dairy                                     In-State
# ..                  ...                                          ...
# 606           Non-dairy                                 Out-of-State
# 607               Dairy                                 Out-of-State
# 608               Dairy                                     In-State
# 609               Dairy                                     In-State
# 610               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 1                           No  ...
# 5                          Yes  ...
# 6                           No  ...
# 9                          Yes  ...
# 13                          No  ...
# ..                         ...  ...
# 606                         No  ...
# 607                         No  ...
# 608                        Yes  ...
# 609                         No  ...
# 610                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 1                                              Sweeden
# 5                                               Greece
# 6                                                China
# 9                                                  NaN
# 13                                              France
# ..                                                 ...
# 606                                              Japan
# 607                                             Taiwan
# 608                                              India
# 609                                             Norway
# 610                                              Korea
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 1                    Shawarma Joint                      Siebel Center
# 5                       thai fusion                                CIF
# 6                          Chipotle                               Home
# 9                               NaN                                NaN
# 13                      Mcdonald’s                             My room
# ..                              ...                                ...
# 606                             Evo                               Dorm
# 607                Northern Cuisine                            My dorm
# 608                    Bangkok Thai                                CIF
# 609                       McDonalds                            Library
# 610                 Northern Cusine                                CIF
#
#     What genre of music do you like the most?  \
# 1                                         Pop
# 5                                   pop/indie
# 6                                         Pop
# 9                                         NaN
# 13                                        Rap
# ..                                        ...
# 606                                       Pop
# 607                                     J-pop
# 608                                       pop
# 609                                     R & B
# 610                                       Rap
#
#     What is your favorite school subject?  \
# 1                                      CS
# 5                                    Math
# 6                                   Stats
# 9                                     NaN
# 13                                  Stats
# ..                                    ...
# 606                               Finance
# 607                                  Math
# 608                               Science
# 609                        Social Studies
# 610                               English
#
#     What do you think is the hardest major at UIUC?  \
# 1                                  Computer Science
# 5                                              ECE
# 6                                           Physics
# 9                                               NaN
# 13                                         Comp Sci
# ..                                              ...
# 606                                              EE
# 607                          Electrical Engineering
# 608                                              CS
# 609                            Computer Engineering
# 610                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 1                         Taylor Swift                                YouTube
# 5                      Phoebe Bridgers                              Instagram
# 6                             Coldplay                                WeChat
# 9                         taylor swift                              pinterest
# 13                              J Cole                                Twitter
# ..                                 ...                                    ...
# 606                            Yoasobi                                   Line
# 607                Lilas Ikuta (Ikura)                               Facebook
# 608                              Drake                              Instagram
# 609                      Daniel Ceaser                              Instagram
# 610                        Don Toliver                                 Tiktok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 5                                             Fortnite
# 6                                          Hearthstone
# 9                                                  NaN
# 13                                          Basketball
# ..                                                 ...
# 606                                            Genshin
# 607                                     Genshin Impact
# 608                                         Mario Kart
# 609                                           Fortnite
# 610                                      Hide and Seek
#
#     Where is your dream vacation spot?
# 1                            Mountains
# 5                               Greece
# 6                             Maldives
# 9                                  NaN
# 13                              Brazil
# ..                                 ...
# 606                             Europe
# 607                             Hawaii
# 608                               Bali
# 609                      Venice, Italy
# 610                        Switzerland
#
# [305 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5)
df1_treatment
# Out:
#           Name Section Do you like sweet or savory food?  \
# 400       Ezra     Y05                            Savory
# 7    CA Alyssa     Y07                             Sweet
# 425     Johnny     Y14                            Savory
# 532     Olesya     Y07                            Savory
# 340       Maya     Y20                             Sweet
# ..         ...     ...                               ...
# 458    Vivian      Y06                            Savory
# 198   Caroline     Y12                            Savory
# 430      Aiden     Y11                            Savory
# 361  Elizabeth     Y17                             Sweet
# 439     Andrew     Y18                            Savory
#
#     Do you use Windows or Mac?  \
# 400                    Windows
# 7                          Mac
# 425                    Windows
# 532                        Mac
# 340                        Mac
# ..                         ...
# 458                        Mac
# 198                        Mac
# 430                        Mac
# 361                        Mac
# 439                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 400                                 When it's released
# 7                                         Near the end
# 425                                       Near the end
# 532                                       Near the end
# 340                                       Near the end
# ..                                                 ...
# 458                                       Near the end
# 198                                 When it's released
# 430                                       Near the end
# 361                                 When it's released
# 439                                       Near the end
#
#     Are you a morning person?  \
# 400      NOT a Morning Person
# 7              Morning Person
# 425            Morning Person
# 532      NOT a Morning Person
# 340      NOT a Morning Person
# ..                        ...
# 458      NOT a Morning Person
# 198            Morning Person
# 430      NOT a Morning Person
# 361      NOT a Morning Person
# 439      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 400                                                 No
# 7                                                  Yes
# 425                                                 No
# 532                                                 No
# 340                                                 No
# ..                                                 ...
# 458                                                 No
# 198                                                Yes
# 430                                                 No
# 361                                                Yes
# 439                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 400           Non-dairy                                     In-State
# 7             Non-dairy                                     In-State
# 425               Dairy                                     In-State
# 532               Dairy                                     In-State
# 340           Non-dairy                                     In-State
# ..                  ...                                          ...
# 458               Dairy                                 Out-of-State
# 198           Non-dairy                                     In-State
# 430               Dairy                                 Out-of-State
# 361           Non-dairy                                 Out-of-State
# 439               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 400                        Yes  ...
# 7                          Yes  ...
# 425                         No  ...
# 532                        Yes  ...
# 340                        Yes  ...
# ..                         ...  ...
# 458                         No  ...
# 198                        Yes  ...
# 430                         No  ...
# 361                        Yes  ...
# 439                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 400                                        Netherlands
# 7                                              england
# 425                            Anywhere in Scandinavia
# 532                                              Spain
# 340                                            Ireland
# ..                                                 ...
# 458                                                NaN
# 198                                     United Kingdom
# 430                                        South Korea
# 361                                             Canada
# 439                                              China
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 400                    Burrito King                       My apartment
# 7                      bangkok thai                       main library
# 425                        Evo Cafe           main library study rooms
# 532                        Chopstix                                BIF
# 340              Pho Noodle Station                                SCD
# ..                              ...                                ...
# 458                      EVO coffee                       main library
# 198                         Sakanya                       Main Library
# 430                        Cravings                               home
# 361                   Bread Company                               MEB
# 439                Midsummer Lounge                       My apartment
#
#     What genre of music do you like the most?  \
# 400                                      Rock
# 7                                         pop
# 425                         rock/classic rock
# 532                                   pop/rap
# 340                               RnB and EDM
# ..                                        ...
# 458                                   musical
# 198                                       pop
# 430                                       Rap
# 361                                       Pop
# 439                                       Rap
#
#     What is your favorite school subject?  \
# 400                               Biology
# 7                              statistics
# 425                         Music or Math
# 532                               Science
# 340                                  Math
# ..                                    ...
# 458                                   Art
# 198                               History
# 430                            accounting
# 361                     Mechanical Design
# 439                            Accounting
#
#        What do you think is the hardest major at UIUC?  \
# 400                               Chemical Engineering
# 7                                                  ece
# 425  Computer Science or like 5 different engineeri...
# 532                                        engineering
# 340                                        STEM majors
# ..                                                 ...
# 458                                          geography
# 198                                   Computer Science
# 430                                                ECE
# 361                            Electrical Engineering
# 439                                                 CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 400                             Sampha                                 Reddit
# 7                        one direction                                twitter
# 425                         Billy Joel                              Instagram
# 532                          21 Savage                                Tik tok
# 340                     Daniel Caesar                               Instagram
# ..                                 ...                                    ...
# 458                     Pasek and Paul                              instagram
# 198                       Taylor Swift                              Pinterest
# 430                             J Cole                              instagram
# 361                      Taylor Swift                              Instagram
# 439                             Eminem                                 Wechat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 400                                         The Finals
# 7                                       stardew valley
# 425                                             soccer
# 532                                         Just Dance
# 340                                             Wordle
# ..                                                 ...
# 458                                   Baldur's Gate 3
# 198                               King's in the corner
# 430                                  League of legends
# 361                                            Soccer
# 439                                         Victoria 3
#
#     Where is your dream vacation spot?
# 400            Anywhere with mountains
# 7                                japan
# 425                              italy
# 532                             Hawaii
# 340                     Somewhere warm
# ..                                 ...
# 458                           my house
# 198                             Monaco
# 430                             Hawaii
# 361                            Iceland
# 439                              Swiss
#
# [148 rows x 133 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[~df1.index.isin(df1_treatment.index)]
df1_control
# Out:
#            Name Section Do you like sweet or savory food?  \
# 1    Prof. Wade     AL1                            Savory
# 4           Ash     Y17                             Sweet
# 10        Chris     Y06                            Savory
# 18          Max     Y10                            Savory
# 19       Priyal     Y10                            Savory
# ..          ...     ...                               ...
# 587   CA Yuheng     Y16                            Savory
# 590   CA Areeba     Y14                             Sweet
# 592  TA Aakriti     Y08                             Sweet
# 602       Tasso     Y12                            Savory
# 608      Afnaan     Y01                            Savory
#
#     Do you use Windows or Mac?  \
# 1                      Windows
# 4                      Windows
# 10                     Windows
# 18                         Mac
# 19                     Windows
# ..                         ...
# 587                        Mac
# 590                    Windows
# 592                    Windows
# 602                    Windows
# 608                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 1                                   When it's released
# 4                                   When it's released
# 10                                  When it's released
# 18                                        Near the end
# 19                                        Near the end
# ..                                                 ...
# 587                                       Near the end
# 590                                 When it's released
# 592                                 When it's released
# 602                                       Near the end
# 608                                       Near the end
#
#     Are you a morning person?  \
# 1        NOT a Morning Person
# 4        NOT a Morning Person
# 10             Morning Person
# 18       NOT a Morning Person
# 19       NOT a Morning Person
# ..                        ...
# 587      NOT a Morning Person
# 590            Morning Person
# 592      NOT a Morning Person
# 602      NOT a Morning Person
# 608      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 1                                                  Yes
# 4                                                   No
# 10                                                  No
# 18                                                  No
# 19                                                  No
# ..                                                 ...
# 587                                                Yes
# 590                                                Yes
# 592                                                 No
# 602                                                 No
# 608                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 1                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# 10            Non-dairy                                     In-State
# 18                Dairy                                 Out-of-State
# 19                Dairy                                 Out-of-State
# ..                  ...                                          ...
# 587               Dairy                                 Out-of-State
# 590               Dairy                                 Out-of-State
# 592               Dairy                                 Out-of-State
# 602               Dairy                                     In-State
# 608               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 1                           No  ...
# 4                           No  ...
# 10                          No  ...
# 18                          No  ...
# 19                          No  ...
# ..                         ...  ...
# 587                         No  ...
# 590                         No  ...
# 592                         No  ...
# 602                        Yes  ...
# 608                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 1                                              Sweeden
# 4                                                Italy
# 10                                               Italy
# 18                                               Japan
# 19                                              France
# ..                                                 ...
# 587                                              Spain
# 590                                                 UK
# 592                                          Singapore
# 602                                        switzerland
# 608                                              India
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 1                    Shawarma Joint                      Siebel Center
# 4                      Burrito King                      Cafe Paradiso
# 10               Spoonhouse kitchen                               Eceb
# 18                         Chipotle                                Hub
# 19                             Naya                            My room
# ..                              ...                                ...
# 587                             ISR                       Funk library
# 590                     bangok thai                           Grainger
# 592                            Naya                                CIF
# 602                         mia zas                           room 102
# 608                    Bangkok Thai                                CIF
#
#     What genre of music do you like the most?  \
# 1                                         Pop
# 4                                         Pop
# 10                                   Alt-Rock
# 18                                       JPop
# 19                                Dance music
# ..                                        ...
# 587                                   hip-hop
# 590                                       Pop
# 592                                     Indie
# 602                                       rap
# 608                                       pop
#
#     What is your favorite school subject?  \
# 1                                      CS
# 4                                   Stats
# 10                                Physics
# 18                              badminton
# 19                               Accounts
# ..                                    ...
# 587                               Physics
# 590                            algorithms
# 592                                  Math
# 602                               History
# 608                               Science
#
#     What do you think is the hardest major at UIUC?  \
# 1                                  Computer Science
# 4                                       Engineering
# 10                            Computer Engineering
# 18                                             mine
# 19                                               CS
# ..                                              ...
# 587                                         physics
# 590                                              CS
# 592                                              CS
# 602                                              CS
# 608                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 1                         Taylor Swift                                YouTube
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# 10                                Muse                                  Venmo
# 18                           Yorushika                              Instagram
# 19                        Taylor Swift                              Instagram
# ..                                 ...                                    ...
# 587                         Mac Miller                                Be.real
# 590                    Olivia Rodriguo                                  Insta
# 592                       Lukas Graham                              Instagram
# 602                              drake                                  insta
# 608                              Drake                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 4                                              Pokemon
# 10                                         Gang beasts
# 18                                      Lethal Company
# 19                                                 GTA
# ..                                                 ...
# 587                                         video game
# 590                                              chess
# 592                                              Chess
# 602                                           baseball
# 608                                         Mario Kart
#
#     Where is your dream vacation spot?
# 1                            Mountains
# 4                              Itality
# 10                                Mars
# 18                           Singapore
# 19                               Paris
# ..                                 ...
# 587                      space station
# 590                             hawaii
# 592                              Dubai
# 602                            iceland
# 608                               Bali
#
# [147 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5)
df2_treatment
# Out:
#          Name Section Do you like sweet or savory food?  \
# 143   Mengjia     Y19                             Sweet
# 83    Allison     Y13                             Sweet
# 575    Rayhan     Y17                            Savory
# 85       Gabe     Y14                             Sweet
# 156      Abby     Y18                            Savory
# ..        ...     ...                               ...
# 561     Vedha     Y14                             Sweet
# 536       Sam     Y13                             Sweet
# 333      Alex     Y06                             Sweet
# 371  Jonathan     Y18                            Savory
# 519   Orlando     Y01                            Savory
#
#     Do you use Windows or Mac?  \
# 143                    Windows
# 83                         Mac
# 575                    Windows
# 85                     Windows
# 156                    Windows
# ..                         ...
# 561                    Windows
# 536                        Mac
# 333                        Mac
# 371                        Mac
# 519                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 143                                       Near the end
# 83                                  When it's released
# 575                                       Near the end
# 85                                  When it's released
# 156                                 When it's released
# ..                                                 ...
# 561                                       Near the end
# 536                                       Near the end
# 333                                 When it's released
# 371                                       Near the end
# 519                                       Near the end
#
#     Are you a morning person?  \
# 143      NOT a Morning Person
# 83       NOT a Morning Person
# 575      NOT a Morning Person
# 85             Morning Person
# 156      NOT a Morning Person
# ..                        ...
# 561      NOT a Morning Person
# 536      NOT a Morning Person
# 333      NOT a Morning Person
# 371      NOT a Morning Person
# 519      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 143                                                Yes
# 83                                                  No
# 575                                                 No
# 85                                                  No
# 156                                                 No
# ..                                                 ...
# 561                                                 No
# 536                                                 No
# 333                                                 No
# 371                                                 No
# 519                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 143           Non-dairy                                 Out-of-State
# 83                Dairy                                     In-State
# 575               Dairy                                     In-State
# 85                Dairy                                     In-State
# 156               Dairy                                     In-State
# ..                  ...                                          ...
# 561               Dairy                                 Out-of-State
# 536               Dairy                                 Out-of-State
# 333               Dairy                                 Out-of-State
# 371               Dairy                                 Out-of-State
# 519               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 143                         No  ...
# 83                          No  ...
# 575                         No  ...
# 85                          No  ...
# 156                         No  ...
# ..                         ...  ...
# 561                         No  ...
# 536                         No  ...
# 333                         No  ...
# 371                         No  ...
# 519                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 143                                              China
# 83                                     The Netherlands
# 575                                                 UK
# 85                                         Switzerland
# 156                                              Italy
# ..                                                 ...
# 561                                              Paris
# 536                                        Switzerland
# 333                                              China
# 371                                              China
# 519                                             Canada
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 143                              no                                 no
# 83                     Bangkok Thai              Wardall Honors Lounge
# 575                  Shawarma Joint                            Library
# 85                           Vinnys                       Main Library
# 156                  Shawarma Joint                       Main Library
# ..                              ...                                ...
# 561                        Sakanaya          Library- main or grainger
# 536              Dave's Hot Chicken                            My room
# 333                     Newman Hall                       Main Library
# 371                        Evo Cafe                               Dorm
# 519                      McDonald's                           Grainger
#
#     What genre of music do you like the most?  \
# 143                                   hip-pop
# 83                                        NaN
# 575                                      Rap
# 85                                      Indie
# 156                                       Pop
# ..                                        ...
# 561                                       NaN
# 536                                       Pop
# 333                                       Pop
# 371                                       Pop
# 519                                       Pop
#
#     What is your favorite school subject?  \
# 143                           pet science
# 83                                English
# 575                                   Gym
# 85                                   Math
# 156                                  Math
# ..                                    ...
# 561                                  Math
# 536                                  Math
# 333                             Economics
# 371                                  Math
# 519                      Computer Science
#
#     What do you think is the hardest major at UIUC?  \
# 143                                computer science
# 83                                              NaN
# 575                                        Comp Sci
# 85                            Aerospace Engineering
# 156                            Computer Engineering
# ..                                              ...
# 561                                             NaN
# 536                                         Physics
# 333                                Computer Science
# 371                                              EE
# 519                                             ECE
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 143                                 no                                 tiktok
# 83                                 NaN                                 TikTok
# 575                       Travis Scott                              Instagram
# 85                               Caamp                              Instagram
# 156                     Chase Atlantic                                YouTube
# ..                                 ...                                    ...
# 561                                NaN                              Instagram
# 536                         Ed Sheeran                              Instagram
# 333                      Justin Bieber                              Instagram
# 371                           Jay Chou                                 Wechat
# 519                       Lana Del Rey                                Youtube
#
#     What is your favorite game to play (either video game or IRL)?  \
# 143                                           Palworld
# 83                                             Genshin
# 575                                           Football
# 85                                 My singing monsters
# 156                                           Splendor
# ..                                                 ...
# 561                                          Badminton
# 536                                             Soccer
# 333                                           Valorant
# 371                                     Genshin Impact
# 519                                            Genshin
#
#     Where is your dream vacation spot?
# 143                                NaN
# 83                              Greece
# 575                    Northern Lights
# 85                          Interlaken
# 156                              Italy
# ..                                 ...
# 561                             Greece
# 536                          Barcelona
# 333                             France
# 371                              Japan
# 519                               Fiji
#
# [156 rows x 133 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[~df2.index.isin(df2_treatment.index)]
df2_control
# Out:
#           Name Section Do you like sweet or savory food?  \
# 3        Keiji     Y13                             Sweet
# 6          Max     Y02                            Savory
# 12   Shubhayon     Y19                            Savory
# 17      Nathan     Y13                             Sweet
# 21       Lhaye     Y14                            Savory
# ..         ...     ...                               ...
# 594    Bernice     Y04                            Savory
# 600       Eric     Y19                             Sweet
# 604    Hongyou     Y15                             Sweet
# 605   LaKeisha     Y15                            Savory
# 610      Ellyn     Y2-                            Savory
#
#     Do you use Windows or Mac?  \
# 3                      Windows
# 6                      Windows
# 12                     Windows
# 17                         Mac
# 21                         Mac
# ..                         ...
# 594                        Mac
# 600                    Windows
# 604                        Mac
# 605                        Mac
# 610                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 3                                   When it's released
# 6                                         Near the end
# 12                                  When it's released
# 17                                  When it's released
# 21                                  When it's released
# ..                                                 ...
# 594                                       Near the end
# 600                                 When it's released
# 604                                       Near the end
# 605                                 When it's released
# 610                                       Near the end
#
#     Are you a morning person?  \
# 3              Morning Person
# 6        NOT a Morning Person
# 12       NOT a Morning Person
# 17       NOT a Morning Person
# 21       NOT a Morning Person
# ..                        ...
# 594            Morning Person
# 600      NOT a Morning Person
# 604            Morning Person
# 605      NOT a Morning Person
# 610      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 3                                                  Yes
# 6                                                  Yes
# 12                                                  No
# 17                                                  No
# 21                                                  No
# ..                                                 ...
# 594                                                Yes
# 600                                                 No
# 604                                                Yes
# 605                                                Yes
# 610                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 3                 Dairy                                     In-State
# 6                 Dairy                                 Out-of-State
# 12                Dairy                                 Out-of-State
# 17            Non-dairy                                     In-State
# 21            Non-dairy                                     In-State
# ..                  ...                                          ...
# 594           Non-dairy                                     In-State
# 600               Dairy                                 Out-of-State
# 604               Dairy                                 Out-of-State
# 605           Non-dairy                                     In-State
# 610               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 3                           No  ...
# 6                           No  ...
# 12                          No  ...
# 17                          No  ...
# 21                         Yes  ...
# ..                         ...  ...
# 594                         No  ...
# 600                         No  ...
# 604                        Yes  ...
# 605                         No  ...
# 610                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 3                                                japan
# 6                                                China
# 12                                                 NaN
# 17                                              Sweden
# 21                                         New Zealand
# ..                                                 ...
# 594                                              Japan
# 600                                              China
# 604                                                NaN
# 605                                            Greece
# 610                                              Korea
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 3                              yogi                               main
# 6                          Chipotle                               Home
# 12                              NaN                          Dorm room
# 17                        Black Dog                               Dorm
# 21                       Basil Thai                      Main Library
# ..                              ...                                ...
# 594                            Yogi                                CIF
# 600                        Cravings                             Loomis
# 604                             NaN                                NaN
# 605                        Juanitos                                CIF
# 610                 Northern Cusine                                CIF
#
#     What genre of music do you like the most?  \
# 3                                         rap
# 6                                         Pop
# 12                                        NaN
# 17                                    Country
# 21                                      Indie
# ..                                        ...
# 594                                       Pop
# 600                                       pop
# 604                                       NaN
# 605                                   Hip hop
# 610                                       Rap
#
#     What is your favorite school subject?  \
# 3                                    math
# 6                                   Stats
# 12                                   Math
# 17                                   Math
# 21                                Science
# ..                                    ...
# 594                               Science
# 600                                   NaN
# 604                                   NaN
# 605                                   Idk
# 610                               English
#
#     What do you think is the hardest major at UIUC?  \
# 3                                          pre med
# 6                                           Physics
# 12                                              ECE
# 17                                Chemical Engineer
# 21                           Aerospace Engineering
# ..                                              ...
# 594                            Chemical Engineering
# 600                           Computer Engineering
# 604                                             NaN
# 605                                         Physics
# 610                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 3                          post malone                                  insta
# 6                             Coldplay                                WeChat
# 12                                 NaN                                Twitter
# 17                          Zach Bryan                                 Tiktok
# 21                        Beabadoobee                                  Tiktok
# ..                                 ...                                    ...
# 594                                SZA                              Instagram
# 600                                NaN                               discord
# 604                                NaN                                    NaN
# 605                                Idk                                TikTok
# 610                        Don Toliver                                 Tiktok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                                      clash of clans
# 6                                          Hearthstone
# 12                                         Basketball
# 17                                        MLB The Show
# 21                                                Sims
# ..                                                 ...
# 594                                            Hay Day
# 600                                                NaN
# 604                                                NaN
# 605                                              WiiU
# 610                                      Hide and Seek
#
#     Where is your dream vacation spot?
# 3                               greece
# 6                             Maldives
# 12                                 NaN
# 17                             Iceland
# 21                             Palawan
# ..                                 ...
# 594                             Sweden
# 600                                NaN
# 604                                NaN
# 605                          Bora Bora
# 610                        Switzerland
#
# [157 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment, df2_treatment])
treatment
# Out:
#           Name Section Do you like sweet or savory food?  \
# 400       Ezra     Y05                            Savory
# 7    CA Alyssa     Y07                             Sweet
# 425     Johnny     Y14                            Savory
# 532     Olesya     Y07                            Savory
# 340       Maya     Y20                             Sweet
# ..         ...     ...                               ...
# 561      Vedha     Y14                             Sweet
# 536        Sam     Y13                             Sweet
# 333       Alex     Y06                             Sweet
# 371   Jonathan     Y18                            Savory
# 519    Orlando     Y01                            Savory
#
#     Do you use Windows or Mac?  \
# 400                    Windows
# 7                          Mac
# 425                    Windows
# 532                        Mac
# 340                        Mac
# ..                         ...
# 561                    Windows
# 536                        Mac
# 333                        Mac
# 371                        Mac
# 519                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 400                                 When it's released
# 7                                         Near the end
# 425                                       Near the end
# 532                                       Near the end
# 340                                       Near the end
# ..                                                 ...
# 561                                       Near the end
# 536                                       Near the end
# 333                                 When it's released
# 371                                       Near the end
# 519                                       Near the end
#
#     Are you a morning person?  \
# 400      NOT a Morning Person
# 7              Morning Person
# 425            Morning Person
# 532      NOT a Morning Person
# 340      NOT a Morning Person
# ..                        ...
# 561      NOT a Morning Person
# 536      NOT a Morning Person
# 333      NOT a Morning Person
# 371      NOT a Morning Person
# 519      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 400                                                 No
# 7                                                  Yes
# 425                                                 No
# 532                                                 No
# 340                                                 No
# ..                                                 ...
# 561                                                 No
# 536                                                 No
# 333                                                 No
# 371                                                 No
# 519                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 400           Non-dairy                                     In-State
# 7             Non-dairy                                     In-State
# 425               Dairy                                     In-State
# 532               Dairy                                     In-State
# 340           Non-dairy                                     In-State
# ..                  ...                                          ...
# 561               Dairy                                 Out-of-State
# 536               Dairy                                 Out-of-State
# 333               Dairy                                 Out-of-State
# 371               Dairy                                 Out-of-State
# 519               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 400                        Yes  ...
# 7                          Yes  ...
# 425                         No  ...
# 532                        Yes  ...
# 340                        Yes  ...
# ..                         ...  ...
# 561                         No  ...
# 536                         No  ...
# 333                         No  ...
# 371                         No  ...
# 519                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 400                                        Netherlands
# 7                                              england
# 425                            Anywhere in Scandinavia
# 532                                              Spain
# 340                                            Ireland
# ..                                                 ...
# 561                                              Paris
# 536                                        Switzerland
# 333                                              China
# 371                                              China
# 519                                             Canada
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 400                    Burrito King                       My apartment
# 7                      bangkok thai                       main library
# 425                        Evo Cafe           main library study rooms
# 532                        Chopstix                                BIF
# 340              Pho Noodle Station                                SCD
# ..                              ...                                ...
# 561                        Sakanaya          Library- main or grainger
# 536              Dave's Hot Chicken                            My room
# 333                     Newman Hall                       Main Library
# 371                        Evo Cafe                               Dorm
# 519                      McDonald's                           Grainger
#
#     What genre of music do you like the most?  \
# 400                                      Rock
# 7                                         pop
# 425                         rock/classic rock
# 532                                   pop/rap
# 340                               RnB and EDM
# ..                                        ...
# 561                                       NaN
# 536                                       Pop
# 333                                       Pop
# 371                                       Pop
# 519                                       Pop
#
#     What is your favorite school subject?  \
# 400                               Biology
# 7                              statistics
# 425                         Music or Math
# 532                               Science
# 340                                  Math
# ..                                    ...
# 561                                  Math
# 536                                  Math
# 333                             Economics
# 371                                  Math
# 519                      Computer Science
#
#        What do you think is the hardest major at UIUC?  \
# 400                               Chemical Engineering
# 7                                                  ece
# 425  Computer Science or like 5 different engineeri...
# 532                                        engineering
# 340                                        STEM majors
# ..                                                 ...
# 561                                                NaN
# 536                                            Physics
# 333                                   Computer Science
# 371                                                 EE
# 519                                                ECE
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 400                             Sampha                                 Reddit
# 7                        one direction                                twitter
# 425                         Billy Joel                              Instagram
# 532                          21 Savage                                Tik tok
# 340                     Daniel Caesar                               Instagram
# ..                                 ...                                    ...
# 561                                NaN                              Instagram
# 536                         Ed Sheeran                              Instagram
# 333                      Justin Bieber                              Instagram
# 371                           Jay Chou                                 Wechat
# 519                       Lana Del Rey                                Youtube
#
#     What is your favorite game to play (either video game or IRL)?  \
# 400                                         The Finals
# 7                                       stardew valley
# 425                                             soccer
# 532                                         Just Dance
# 340                                             Wordle
# ..                                                 ...
# 561                                          Badminton
# 536                                             Soccer
# 333                                           Valorant
# 371                                     Genshin Impact
# 519                                            Genshin
#
#     Where is your dream vacation spot?
# 400            Anywhere with mountains
# 7                                japan
# 425                              italy
# 532                             Hawaii
# 340                     Somewhere warm
# ..                                 ...
# 561                             Greece
# 536                          Barcelona
# 333                             France
# 371                              Japan
# 519                               Fiji
#
# [304 rows x 133 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#            Name Section Do you like sweet or savory food?  \
# 1    Prof. Wade     AL1                            Savory
# 4           Ash     Y17                             Sweet
# 10        Chris     Y06                            Savory
# 18          Max     Y10                            Savory
# 19       Priyal     Y10                            Savory
# ..          ...     ...                               ...
# 594     Bernice     Y04                            Savory
# 600        Eric     Y19                             Sweet
# 604     Hongyou     Y15                             Sweet
# 605    LaKeisha     Y15                            Savory
# 610       Ellyn     Y2-                            Savory
#
#     Do you use Windows or Mac?  \
# 1                      Windows
# 4                      Windows
# 10                     Windows
# 18                         Mac
# 19                     Windows
# ..                         ...
# 594                        Mac
# 600                    Windows
# 604                        Mac
# 605                        Mac
# 610                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 1                                   When it's released
# 4                                   When it's released
# 10                                  When it's released
# 18                                        Near the end
# 19                                        Near the end
# ..                                                 ...
# 594                                       Near the end
# 600                                 When it's released
# 604                                       Near the end
# 605                                 When it's released
# 610                                       Near the end
#
#     Are you a morning person?  \
# 1        NOT a Morning Person
# 4        NOT a Morning Person
# 10             Morning Person
# 18       NOT a Morning Person
# 19       NOT a Morning Person
# ..                        ...
# 594            Morning Person
# 600      NOT a Morning Person
# 604            Morning Person
# 605      NOT a Morning Person
# 610      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 1                                                  Yes
# 4                                                   No
# 10                                                  No
# 18                                                  No
# 19                                                  No
# ..                                                 ...
# 594                                                Yes
# 600                                                 No
# 604                                                Yes
# 605                                                Yes
# 610                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 1                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# 10            Non-dairy                                     In-State
# 18                Dairy                                 Out-of-State
# 19                Dairy                                 Out-of-State
# ..                  ...                                          ...
# 594           Non-dairy                                     In-State
# 600               Dairy                                 Out-of-State
# 604               Dairy                                 Out-of-State
# 605           Non-dairy                                     In-State
# 610               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 1                           No  ...
# 4                           No  ...
# 10                          No  ...
# 18                          No  ...
# 19                          No  ...
# ..                         ...  ...
# 594                         No  ...
# 600                         No  ...
# 604                        Yes  ...
# 605                         No  ...
# 610                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 1                                              Sweeden
# 4                                                Italy
# 10                                               Italy
# 18                                               Japan
# 19                                              France
# ..                                                 ...
# 594                                              Japan
# 600                                              China
# 604                                                NaN
# 605                                            Greece
# 610                                              Korea
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 1                    Shawarma Joint                      Siebel Center
# 4                      Burrito King                      Cafe Paradiso
# 10               Spoonhouse kitchen                               Eceb
# 18                         Chipotle                                Hub
# 19                             Naya                            My room
# ..                              ...                                ...
# 594                            Yogi                                CIF
# 600                        Cravings                             Loomis
# 604                             NaN                                NaN
# 605                        Juanitos                                CIF
# 610                 Northern Cusine                                CIF
#
#     What genre of music do you like the most?  \
# 1                                         Pop
# 4                                         Pop
# 10                                   Alt-Rock
# 18                                       JPop
# 19                                Dance music
# ..                                        ...
# 594                                       Pop
# 600                                       pop
# 604                                       NaN
# 605                                   Hip hop
# 610                                       Rap
#
#     What is your favorite school subject?  \
# 1                                      CS
# 4                                   Stats
# 10                                Physics
# 18                              badminton
# 19                               Accounts
# ..                                    ...
# 594                               Science
# 600                                   NaN
# 604                                   NaN
# 605                                   Idk
# 610                               English
#
#     What do you think is the hardest major at UIUC?  \
# 1                                  Computer Science
# 4                                       Engineering
# 10                            Computer Engineering
# 18                                             mine
# 19                                               CS
# ..                                              ...
# 594                            Chemical Engineering
# 600                           Computer Engineering
# 604                                             NaN
# 605                                         Physics
# 610                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 1                         Taylor Swift                                YouTube
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# 10                                Muse                                  Venmo
# 18                           Yorushika                              Instagram
# 19                        Taylor Swift                              Instagram
# ..                                 ...                                    ...
# 594                                SZA                              Instagram
# 600                                NaN                               discord
# 604                                NaN                                    NaN
# 605                                Idk                                TikTok
# 610                        Don Toliver                                 Tiktok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 4                                              Pokemon
# 10                                         Gang beasts
# 18                                      Lethal Company
# 19                                                 GTA
# ..                                                 ...
# 594                                            Hay Day
# 600                                                NaN
# 604                                                NaN
# 605                                              WiiU
# 610                                      Hide and Seek
#
#     Where is your dream vacation spot?
# 1                            Mountains
# 4                              Itality
# 10                                Mars
# 18                           Singapore
# 19                               Paris
# ..                                 ...
# 594                             Sweden
# 600                                NaN
# 604                                NaN
# 605                          Bora Bora
# 610                        Switzerland
#
# [304 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."
assert(
  (len(treatment) + len(control) == len(df1) + len(df2)) or
  (len(treatment) + len(control) == len(df))
), f"Not everyone in the dataset (or everyone who responded to the question being blocked) is included in one of the two groups -- someone is missing! :(\nPeople in treatment group: {len(treatment)}\nPeople in control group: {len(control)}\nTotal in treatment+control group: {len(control) + len(treatment)}\n== vs ==\nTotal people in dataset: {len(df)}\nTotal people with data for blocking: {len(df1) + len(df2)}"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q6: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# *Blocking is when you have a small sample size of the same make up to get a better outcome. Within the sample a person can randomly compare the diffrences in the group. Blocking allows you to be very specific with your group.
